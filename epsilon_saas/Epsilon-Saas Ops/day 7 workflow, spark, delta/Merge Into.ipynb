# %%
https://docs.delta.io/latest/delta-update.html#upsert-into-a-table-using-merge

# %%
Merge into
1. cdc: change data capture
2. No duplicates
3. UpSert: UPdate and inSert, delete

# %%
data=([(1,"Naval","India",'Insert'),(2,'Om','US','Insert')])
schema="id int , name string, country string, operation string"
df=spark.createDataFrame(data,schema)
df.createOrReplaceTempView("source")

# %%
data=([(1,"Naval","UK",'Update'),(3,'David','US','Insert')])
schema="id int , name string, country string, operation string"
df=spark.createDataFrame(data,schema)
df.createOrReplaceTempView("source")

# %%
data=([(1,"Naval","UK",'Delete'),(3,'David','India','Update'),(4,'Velentina','India','Insert')])
schema="id int , name string, country string, operation string"
df=spark.createDataFrame(data,schema)
df.createOrReplaceTempView("source")

# %%
# %sql
select * from source

# %%
# %sql
create table saas.naval_silver.employee(id int, name string, country string)

# %%
# %sql
MERGE INTO saas.naval_silver.employee t
USING source s
ON t.id = s.id
WHEN MATCHED and s.operation='Delete'
then delete
WHEN MATCHED THEN
  UPDATE SET
   t.name=s.name,
   t.country=s.country
WHEN NOT MATCHED
  THEN INSERT (
    id,
   name,
   country
  )
  VALUES (
    s.id,
    s.name,
    s.country
  )

# %%
# %sql
select * from saas.naval_silver.employee

# %%
# %sql
describe history saas.naval_silver.employee
